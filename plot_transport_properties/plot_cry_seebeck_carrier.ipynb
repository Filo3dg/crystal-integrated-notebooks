# %% [markdown]
# # Plot the Seebeck coefficient with respect to the charge carrier concentration

# %%
from crystal_functions.file_readwrite import *
from crystal_functions.plot import *

# %% [markdown]
# Read a SEEBECK.DAT file

# %%
seebeck = Properties_output().read_cry_seebeck('../data/bi2te3_SEEBECK.DAT')

# %% [markdown]
# Plot the Seebeck with respect to the chemical potential

# %%
plot_cry_seebeck_carrier(seebeck)
# Out:
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yx, S_yy, S_yz, S_yz, S_zx, S_zy, S_zz
# sxx
