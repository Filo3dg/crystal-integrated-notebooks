# %% [markdown]
# # Plot the Power Factor with respect to the chemical potential

# %%
from crystal_functions.file_readwrite import *
from crystal_functions.plot import *

# %% [markdown]
# Read a SEEBECK.DAT file

# %%
seebeck = Properties_output().read_cry_seebeck('../data/bi2te3_SEEBECK.DAT')

# %% [markdown]
# Read a SIGMA.DAT file

# %%
sigma = Properties_output().read_cry_sigma('../data/bi2te3_SIGMA.DAT')

# %% [markdown]
# Plot the Power Factor with respect to the chemical potential

# %%
plot_cry_powerfactor(seebeck,sigma)
# Out:
# Please, choose the direction you want to plot.
# You can choose among PF_xx, PF_xy, PF_xz, PF_yx, PF_yy, PF_yz, PF_yz, PF_zx, PF_zy, PF_zz
# pfxx
