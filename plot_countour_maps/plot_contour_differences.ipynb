# %% [markdown]
# # PL2D PLOT

# %% [markdown]
# This is the notebook to plot the unities from PL2D calculation

# %%
from crystal_functions.file_readwrite import *
from crystal_functions.plot import *

# %%
#COLAB users
#from google.colab import files
#uploaded = files.upload()

# %%
ls
# Out:
# PL2D.ipynb              pl2d_cry.SURFRHOO       pl2d_cry_pato.SURFRHOO

# %%
urea_contour_plot = Properties_output().read_cry_contour('./pl2d_cry.SURFRHOO')

# %%
urea_contour_plot

# %%
plot_cry_contour(urea_contour_plot)
# Out:
# The image has been saved in the current directory

# %%
urea_contour_plot_ref = Properties_output().read_cry_contour('pl2d_cry_pato.SURFRHOO')

# %%
urea_contour_plot_ref

# %%
plot_cry_contour_differences(urea_contour_plot,urea_contour_plot_ref)
# Out:
# The image has been saved in the current directory

# %%
ls
# Out:
# PL2D.ipynb
# figure_SURFRHOO_2022-09-20_164846.jpg
# figure_diff_SURFRHOO_2022-09-20_165015.jpg
# pl2d_cry.SURFRHOO
# pl2d_cry_pato.SURFRHOO

# %%
#alessandro.cossard@unito.it
